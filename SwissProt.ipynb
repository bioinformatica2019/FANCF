# %%
from Bio import ExPASy
handle = ExPASy.get_sprot_raw("Q9NPI8")
from Bio import SwissProt
record = SwissProt.read(handle)


print(record.description)
print("\n")
for ref in record.references:
    print ("autores:", ref.authors)
    print ("titulo:", ref.title)
    print("\n")
# Out:
# RecName: Full=Fanconi anemia group F protein; Short=Protein FACF;
#
#
# autores: de Winter J.P., Rooimans M.A., van der Weel L., van Berkel C.G.M., de Groot J., Waisfisz Q., Pronk J.C., Arwert F., Mathew C.G., Scheper R.J., Hoatlin M.E., Buchwald M., Joenje H.
# titulo: The Fanconi anaemia gene FANCF encodes a novel protein with homology to ROM.
#
#
# ...

# %%
from Bio.SwissProt import KeyWList

handle = open("swissprot_k.txt")
records= KeyWList.parse(handle)

for record in records:
    print("\n")
    print("nome/revista?/numero de aminoacidos:",record["ID"])
    print("descrição:", record["DE"])
    print("numero primário/secundário de acesso:",record["AC"])
# Out:
# Ignoring: DT   10-OCT-2002, integrated into UniProtKB/Swiss-Prot.
# Ignoring: DT   01-OCT-2000, sequence version 1.
# Ignoring: DT   13-NOV-2019, entry version 157.
# Ignoring: GN   Name=FANCF;
# Ignoring: OS   Homo sapiens (Human).
# Ignoring: OC   Eukaryota; Metazoa; Chordata; Craniata; Vertebrata; Euteleostomi;
# Ignoring: OC   Mammalia; Eutheria; Euarchontoglires; Primates; Haplorrhini;
# Ignoring: OC   Catarrhini; Hominidae; Homo.
# Ignoring: OX   NCBI_TaxID=9606;
# Ignoring: RN   [1]
# Ignoring: RP   NUCLEOTIDE SEQUENCE [MRNA], AND INVOLVEMENT IN FANCF.
# Ignoring: RX   PubMed=10615118; DOI=10.1038/71626;
# Ignoring: RA   de Winter J.P., Rooimans M.A., van der Weel L., van Berkel C.G.M.,
# Ignoring: RA   de Groot J., Waisfisz Q., Pronk J.C., Arwert F., Mathew C.G.,
# Ignoring: RA   Scheper R.J., Hoatlin M.E., Buchwald M., Joenje H.;
# Ignoring: RT   "The Fanconi anaemia gene FANCF encodes a novel protein with homology
# Ignoring: RT   to ROM.";
# ...
